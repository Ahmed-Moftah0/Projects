# %%
class Student :
    def __init__(self,Student_Full_Name,Student_ID,Student_Email,Student_Password,Student_Dept,Student_payment,Student_Level):
        
            
            self.Fname=Student_Full_Name
            
            self.ID=Student_ID
            
            self.Email=Student_Email
            
            self.Password=Student_Password
            
            self.ST_Level=Student_Level
            
            self.Dept=Student_Dept
             
            self.StPayment=Student_payment
             
            
    def describe_user(self):
        print("Full Name",":",self.Fname)
        print("ID",":",self.ID)
        print("Email",":",self.Email)
        print("Password",":", self.Password)
        print("Dept",":",self.Dept)
#         print("Enroll_Course" + " : " + self.Enroll_Course)
        print("StPayment",":",self.StPayment)
        print("ST_Level",":",self.ST_Level)
        
  
    
# def ask_user(message=''):
#     user_input = ''
#     while not user_input:
#         user_input = input(message)
#     return user_input
        
      





class courses(Student):
    def init(self,ST_Level,Dept):
        super.init(ST_Level,Dept)
        
    @classmethod    
    def level(cls):
        print(""" Enter your number of level
        1-level one
        2-level two
        3-level three
        4-level four
         """)
        ST_Level=int(input(" "))
        if ST_Level==1 or ST_Level==2:
            print("the level one and two do not have depts")
            print(""" and your courses in the first semester are :
        1-A
        2-B
        3-C
        4-D
        5-E
        
        and your courses in the SECOND semster are :
        
        1-F
        2-G
        3-H
        4-J
        5-K
        
         """)
            
        elif ST_Level==3 or ST_Level==4:
            

            dd = dept.Department(ST_Level)
        return ST_Level
        
class dept(courses):
    def init(self,Dept,ST_Level):
        super.init(Dept,ST_Level)
        
    
    @classmethod
    def Department(cls,ST_Level):
        
        if int(ST_Level)== 3 or int(ST_Level)== 4:

            Dept=input("Enter Department ")
                
            if Dept.lower()=="cs":
                print(""" and your courses in the first semester are :
        1-A
        2-B
        3-C
        4-D
        5-E
        
        and your courses in the SECOND semster are :
        
        1-F
        2-G
        3-H
        4-J
        5-K
        
         """)
            elif Dept.lower()=="it":
                print(""" and your courses in the first semester are :
        1-A
        2-B
        3-C
        4-D
        5-E
        
        and your courses in the SECOND semster are :
        
        1-F
        2-G
        3-H
        4-J
        5-K
        
         """)
            elif Dept.lower()=="se":
                print(""" and your courses in the first semester are :
        1-A
        2-B
        3-C
        4-D
        5-E
        
        and your courses in the SECOND semster are :
        
        1-F
        2-G
        3-H
        4-J
        5-K
        
         """)
            else:
                print(""" and your courses in the first semester are :
        1-A
        2-B
        3-C
        4-D
        5-E
        
        and your courses in the SECOND semster are :
        
        1-F
        2-G
        3-H
        4-J
        5-K
        
         """)
        else :
            Dept=0
        if ST_Level > 2:
            return Dept
        
class DR:
    def __init__(self,Dr_Full_Name,Dr_Salary,Dr_exprance,Dr_Course,Dr_Email,Dr_Password,Dr_ID,Department_Dr):
        self.Dname=Dr_Full_Name
        self.Dsalary=Dr_Salary
        self.Dexprance=Dr_exprance
        self.Dcouse=Dr_Course
        self.DEmail=Dr_Email
        self.Dpassword=Dr_Password
        self.DID=Dr_ID
        self.D_Dept=Department_Dr
        
        
    def describe_user(self):
        print("Full Name" + " : " + self.Dname)
        print("ID" + " : " + self.DID)
        print("Email" + " : " + self.DEmail)
        print("Password" + " : " + self.DPassword)
        print("Experance" + " : " + self.Dexprance)
        print("Salary" + " : " + self.Dsalary)
        print("Dept" + " : " + self.D_Dept)
        
        
        
              
def form_complete_DR(values1, placement1):
    placement1=[]

    Dname = input("Enter Full Name: ")
    DID =  input("Enter Id: ")
    DEmail = input(" Email: ")
    Dpassword =input("password: ")
    Dexprance=input("Experance: ")
    print("""
          1-CS
          2-IT
          3-Bio""")
    D_Dept=input("Enter YOUR Department : ")
    if (D_Dept=='CS'):
        print("""
                
            The subjects you will teach
            
            1-a
            2-b
            3-c """)
    elif (D_Dept=="IT"):
        print("""
                
            The subjects you will teach
            
            1-a
            2-b
            3-c """)
    elif (D_Dept=="Bio"):
                print("""
                
            The subjects you will teach
            
            1-a
            2-b
            3-c """)
        
    Dsalary = input(" Salary: ")  
            
    values1 = DR(Dname,DID,DEmail,Dpassword,Dexprance,D_Dept,Dsalary)
    placement1.append(values)
            





def form_complete_Student(values, placement):#students , users
    placement = [] # table i database #abdo--> placement 
    j=0
    count=j+1
    for i in range(0,count):

            Fname = input("Enter Full Name: ")
            ID =  input("Enter Id: ")
            Email = input(" Email: ")
            Password =input("password: ")
            
            
            ST_Level = courses.level()
#             if ST_Level > 2:
            Dept=dept.Department(ST_Level)
            StPayment = input(" Payment: ")  
            
            values = Student(Fname,ID,Email,Password,ST_Level,Dept,StPayment)
            values.describe_user()
            placement.append(values)
             
    
def form_complete():
    print(""" ------------------------------------------------------
 |======================================================| 
 |======== Welcome To Student Management System	========|
 |======================================================|
  ------------------------------------------------------

Enter 1 : Dr 
Enter 2 : New Student 
Enter 3 : Student affair """)
    user_input=int(input("enter your number : "))
        
    if(user_input==2):
        form_complete_Student("Student","users")
    elif(user_input==1):
        form_complete_DR("dr","users")
        
            
            
form_complete()
